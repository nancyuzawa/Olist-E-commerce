# %% [markdown]
# **Dataset: Olist E-commerce**
# </br>**Nomes:** Luiz Henrique Nunes Santana - CP3025608 e Nancy Miyuki Yuzawa - CP3025641

# %%
# Instalando todas as dependências no ambiente correto 
# (dentro do próprio notebook para não dar conflito de versão do python)
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib seaborn scikit-learn xgboost mlxtend yellowbrick
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Visualizar os dados

# %%
import pandas as pd

df = pd.read_csv(
    "./olist_customers_dataset.csv",
    encoding="latin1"
)

print(df.head(10))
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %%
df = pd.read_csv(
    "./olist_geolocation_dataset.csv",
    encoding="latin1"
)

print(df.head(10))
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
# 5                         1012       -23.547762       -46.635361
# 6                         1047       -23.546273       -46.641225
# 7                         1013       -23.546923       -46.634264
# 8                         1029       -23.543769       -46.634278
# 9                         1011       -23.547640       -46.636032
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP
# ...

# %%
df = pd.read_csv(
    "./olist_order_items_dataset.csv",
    encoding="latin1"
)

print(df.head(10))
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
df = pd.read_csv(
    "./olist_order_payments_dataset.csv",
    encoding="latin1"
)

print(df.head(10))
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5  298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6  771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7  3d7239c394a212faae122962df514ac7                   1  credit_card
# 8  1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9  0573b5e23cbd798006520e1d5b4c6714                   1       boleto
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# ...

# %%
df = pd.read_csv(
    "./olist_order_reviews_dataset.csv",
    encoding="latin1"
)

print(df.head(10))
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5  15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6  07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7  7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
# 8  a3f6f7f6f433de0aefbb97da197c554c  9c214ac970e84273583ab523dfafd09b
# 9  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# ...

# %%
df = pd.read_csv(
    "./olist_orders_dataset.csv",
    encoding="latin1"
)

print(df.head(10))
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %%
df = pd.read_csv(
    "./olist_products_dataset.csv",
    encoding="latin1"
)

print(df.head(10))
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# ...

# %% [markdown]
# https://www.kaggle.com/code/fldcosta/olist-sales-prediction

# %% [markdown]
# # Seção 1 - Introdução e Motivação

# %% [markdown]
# O grupo trabalhará na **previsão de demandas de volume de vendas e faturamento por categoria de produto com base no histórico pedidos do e-commerce**.
#
# Nesse contexto, a previsão de vendas torna-se essencial para as empresas de comércio eletrônico, pois isso impacta no:
# * Planejamento de estoque;
# * Logística e distribuição
# * Previsão de receita
# * Tomada de decisões mais estratégicas.
#
# Diante disso, para compreender melhor os padrões das vendas, pretendemos explorar/analisar as seguintes questões:
# * Existe tendência temporal de crescimento nas vendas?
# * Quais fatores mais influenciam o valor das vendas?
# * Existem regiões do Brasil com maior volume de vendas?
# * Quais variáveis possuem maior correlação com a variável alvo?
# * Como a sazonalidade e o comportamento temporal influenciam o volume de itens vendidos?
# * De que forma a distribuição geográfica e a categoria do produto impactam o faturamento total?

# %% [markdown]
# # Seção 2 - Descrição da Base de Dados

# %% [markdown]
# A base de dados foi obtida através do site da Kaggle, no link: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce.
#
# Esses dados são reais que mostram os pedidos realizados entre 2016 e 2018 na plataforma Olist.
#
# O dataset Olist é composto por 9 arquivos no formato CSV, em que cada arquivo representa uma tabela distinta. Essas tabelas são conectadas por IDs, formando uma base de dados relacional. Assim, cada linha possui um significado variando de acordo com a tabela analisada.
#
#
# * **olist_customers_dataset**: a linha contém as informações sobre o cliente e a sua localização
# * **olist_geolocation_dataset**: a linha contém informações sobre os CEPs brasileiros e duas coordenadas(latitude e longitude)
# * **olist_order_items_dataset**: a linha contém as informações sobre os itens comprados em cada pedido com dados como o vendedor, o produto, preço e valor do frete.
# * **olist_order_payments_dataset**: informações sobre as opções de pagamento dos pedidos com o ID do pedido, tipo de pagamento, número de parcelas e valor.
# * **olist_order_reviews_dataset**: dados de avaliações do cliente, como a pontuação, título do comentário, mensagem da avaliação e data e hora da publicação.
# * **olist_orders_dataset**: contém dados do pedido, sendo o principal, com dados do status do pedido, a data e hora da compra/aprovação de pagamento, data de entrega e data de entrega que foi estimada.
# * **olist_products_dataset**: informações sobre o produto vendido, como a categoria, quantidade de fotos, o peso em gramas do produto, comprimento, altura, largura em centímetros.
# * **olist_sellers_dataset**: informações sobre os vendedores que processaram o pedido, como os cinco primeiros dígitos do CEP, a cidade e o estado do vendedor.
# * **product_category_name_translation**: a linha mostra o nome da categoria em português e em inglês.
#
# ### Principais atributos utilizados na análise
# Como o objetivo é prever o volume de vendas (`qtd_item`) e o faturamento por categoria, os atributos mais relevantes para esta análise são:
#
# ### Principais Atributos Utilizados na Análise
#
# | Coluna | Tabela | Tipo | Descrição |
# | :--- | :--- | :--- | :--- |
# | **`qtd_item`** | `order_items` | int | **Variável alvo** — Quantidade de itens em cada pedido (campo `order_item_id` renomeado para clareza) |
# | **`price`** | `order_items` | float | **Variável alvo** — Preço unitário, utilizado para calcular o faturamento total por categoria|
# | **`order_purchase_timestamp`** | `orders` | date | Data da compra (convertida para o formato data para permitir análises temporais e sazonais) |
# | **`product_category_name`** | `products` | string | Categoria do produto, utilizada para agrupamentos de faturamento e volume de vendas |
# | **`customer_city`** | `customers` | string | Cidade do cliente, utilizada para analisar a concentração de vendas em centros urbanos|
# | **`review_score`** | `order_reviews` | int | Avaliação do cliente (1–5), utilizada para cruzar desempenho das categorias com satisfação |

# %% [markdown]
# # Seção 3 - Preparação da base de dados (limpeza inicial)

# %% [markdown]
# Foi feita a união com merge das tabelas de dados(orders, products, customers, review).
#
# Durante o processo de preparação do dataset, foi necessário realizar alguns ajustes iniciais para garantir a qualidade e a consistência dos dados. De forma geral, a base não apresentou problemas críticos de organização, porém exigiu etapas importantes de tratamento, principalmente relacionadas a tipos de dados, padronização e validação das informações após o cruzamento das tabelas.
#
# Um dos primeiros pontos verificados foi a existência de registros duplicados, utilizando o método duplicated(). Essa etapa é essencial após operações de junção (merge), já que relacionamentos do tipo um-para-muitos podem gerar duplicidade de linhas. A verificação permitiu validar se o processo de integração das bases manteve a integridade dos dados.
#
# Em seguida, foi realizada a correção dos tipos de dados, especialmente para colunas de datas que estavam no formato de texto (object). Essas colunas foram convertidas para o tipo datetime, o que é fundamental para permitir análises temporais mais precisas. Posteriormente, a coluna de data de compra (order_purchase_timestamp) foi ajustada para conter apenas a data (sem horário), facilitando agregações por dia.
#
# Também foi feito um pequeno ajuste de padronização de nomenclatura, com a renomeação da coluna order_item_id para qtd_item, tornando seu significado mais claro dentro do contexto da análise.
#
# Ao longo da exploração, foram realizadas diversas agregações e agrupamentos para entender o comportamento dos dados, como:
#
# volume de vendas por categoria de produto,
# faturamento por categoria,
# distribuição de vendas por estado e cidade,
# desempenho das categorias com base nas avaliações dos clientes.
#
# Essas análises ajudaram a identificar padrões e preparar os dados para etapas posteriores, como modelagem.
#
# Na construção da base de treinamento, foi feita uma seleção das variáveis mais relevantes, com a remoção de colunas que não agregariam valor ao modelo, como identificadores (order_id, customer_id, etc.) e campos temporais intermediários que não seriam utilizados diretamente.
#
# Sobre dados faltantes (valores nulos), foram realizadas verificações com isna().sum(). Como estratégia de tratamento, optou-se pela remoção das linhas com valores nulos (dropna()), garantindo que o modelo fosse treinado apenas com dados completos. Essa abordagem é adequada quando a quantidade de valores ausentes não compromete significativamente o volume de dados.

# %% [markdown]
# ## 3.1 – Importações e Carregamento dos Dados

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb

from mlxtend.preprocessing import TransactionEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import (mean_squared_error, r2_score, mean_absolute_error, accuracy_score, confusion_matrix)
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier
from yellowbrick.regressor import residuals_plot, prediction_error

# %%
df = {
 'items' : pd.read_csv('./olist_order_items_dataset.csv', encoding='latin1'),
 'orders' : pd.read_csv('./olist_orders_dataset.csv', encoding='latin1'),
 'products' : pd.read_csv('./olist_products_dataset.csv', encoding='latin1'),
 'customers': pd.read_csv('./olist_customers_dataset.csv', encoding='latin1'),
 'review' : pd.read_csv('./olist_order_reviews_dataset.csv', encoding='latin1'),
}

# %% [markdown]
# ## 3.2 – Junção das Tabelas

# %%
# Une as tabelas
merged = df['orders'].merge(df['items'], on='order_id', how='inner')
merged = merged.merge(df['products'], on='product_id', how='inner')
merged = merged.merge(df['customers'], on='customer_id', how='inner')
merged = merged.merge(df['review'], on='order_id', how='left')

merged.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## 3.3 – Verificação de Qualidade dos Dados

# %% [markdown]
# Antes de qualquer transformação, verificamos a existência de registros duplicados e de valores ausentes (nulos) em todas as colunas do DataFrame consolidado:

# %%
# Verificação de duplicatas
merged.duplicated().sum()

# Verificação de valores nulos por coluna
merged.isna().sum()

# Informações gerais do DataFrame
merged.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 113314 entries, 0 to 113313
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113314 non-null  str
#  1   customer_id                    113314 non-null  str
#  2   order_status                   113314 non-null  str
#  3   order_purchase_timestamp       113314 non-null  str
#  4   order_approved_at              113299 non-null  str
#  5   order_delivered_carrier_date   112111 non-null  str
#  6   order_delivered_customer_date  110839 non-null  str
#  7   order_estimated_delivery_date  113314 non-null  str
#  8   order_item_id                  113314 non-null  int64
#  9   product_id                     113314 non-null  str
#  10  seller_id                      113314 non-null  str
#  11  shipping_limit_date            113314 non-null  str
# ...

# %%
# 1. Verificação ANTES da limpeza
print("Nulos antes do dropna:")
print(merged.isna().sum())

# 2. Execução da limpeza
# O dropna() remove as linhas com valores nulos para garantir dados completos 
merged.dropna(inplace=True)
# Out:
# Nulos antes do dropna:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                   15
# order_delivered_carrier_date      1203
# order_delivered_customer_date     2475
# order_estimated_delivery_date        0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# product_category_name             1612
# product_name_lenght               1612
# product_description_lenght        1612
# product_photos_qty                1612
# product_weight_g                    18
# product_length_cm                   18
# product_height_cm                   18
# product_width_cm                    18
# customer_unique_id                   0
# ...

# %%
# 3. Verificação DEPOIS da limpeza
print("\nNulos após o dropna:")
print(merged.isna().sum())
# Out:
# Nulos após o dropna:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# ...

# %% [markdown]
# ## 3.4 – Conversão de Tipos e Renomeação de Colunas

# %%
# Convertendo colunas de data de object para datetime64
merged['order_purchase_timestamp'] = pd.to_datetime(merged['order_purchase_timestamp'])
merged['order_approved_at'] = pd.to_datetime(merged['order_approved_at'])
merged['order_delivered_carrier_date'] = pd.to_datetime(merged['order_delivered_carrier_date'])
merged['order_delivered_customer_date'] = pd.to_datetime(merged['order_delivered_customer_date'])
merged['order_estimated_delivery_date'] = pd.to_datetime(merged['order_estimated_delivery_date'])
merged['shipping_limit_date'] = pd.to_datetime(merged['shipping_limit_date'])

# %%
# Mantendo apenas a data (sem hora) para a coluna de compra
merged['order_purchase_timestamp'] = merged['order_purchase_timestamp'].dt.date

# %%
# Renomeando a coluna order_item_id
merged.rename(columns={'order_item_id': 'qtd_item'}, inplace = True)

# %% [markdown]
# ## 3.5 – Agrupamentos para Análise Exploratória

# %%
# Contagem de itens por pedido e categoria
order_category_counts = merged.groupby(
    ['order_id', 'product_category_name']
)['qtd_item'].count().reset_index()
order_category_counts

# DataFrame completo com todas as dimensões de análise
order_full = merged.groupby([
    'order_id', 'product_category_name', 'customer_id',
    'order_status', 'order_purchase_timestamp', 'order_approved_at',
    'order_delivered_carrier_date', 'order_delivered_customer_date',
    'order_estimated_delivery_date', 'product_id', 'seller_id',
    'shipping_limit_date', 'price', 'freight_value',
    'customer_unique_id', 'customer_city', 'customer_state'
])['qtd_item'].count().reset_index()
order_full
# Out:
#                               order_id   product_category_name  \
# 0     0006ec9db01a64e59a68b2c340bf65a7         cama_mesa_banho
# 1     000aed2e25dbad2f9ddb70584c5a2ded              perfumaria
# 2     00130c0eee84a3d909e75bc08c5c3ca1               alimentos
# 3     001e7cf2ad6bef3ade12ebc56ceaf0f3            beleza_saude
# 4     002175704e8b209f61b9ad5cfd92b60e                   audio
# ...                                ...                     ...
# 9949  ffc5d47e40567b5f153d5cd17138eb89         cama_mesa_banho
# 9950  ffcb98e21b0bf085baf42b16a67732ef        moveis_decoracao
# 9951  ffd6f465cab015b452d398ac1f5d978a        artigos_de_natal
# 9952  ffe48cb3d8485e0cb0405e21192e592f         cama_mesa_banho
# 9953  ffea20c7630343a6cd9e09858c1295cd  informatica_acessorios
#
#                            customer_id order_status order_purchase_timestamp  \
# 0     5d178120c29c61748ea95bac23cb8f25    delivered               2018-07-24
# ...

# %%
# Agrupando os dados pelo identificador do pedido e nome da categoria com o count no número de itens em cada grupo
#order_category_counts = merged.groupby(['order_id', 'product_category_name'])['qtd_item'].count()
#order_category_counts

# %%
# Resetando o indice
#order_category_counts = order_category_counts.reset_index()
#order_category_counts

# %%
# Agrupando os dados pelo identificador do pedido e nome da categoria com o count no número de itens em cada grupo
# order_full = merged.groupby(['order_id', 'product_category_name', 'customer_id',
#                             'order_status', 'order_purchase_timestamp', 'order_approved_at',
#                             'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date',
#                             'product_id', 'seller_id', 'shipping_limit_date',
#                             'price', 'freight_value', 'customer_unique_id',
#                             'customer_city', 'customer_state'])['qtd_item'].count()
#order_full

# %%
# Resetando o indice
#order_full = order_full.reset_index()
#order_full

# %% [markdown]
# # Seção 4 - Questões de exploração (EDA)

# %% [markdown]
# **1. Quais categorias de produtos possuem maior volume de vendas?**
#
# Hipótese: Algumas categorias concentram a maior parte das vendas.
#
# Análise: Foi realizado um agrupamento por product_category_name, considerando a quantidade de itens vendidos (qtd_item).
#
# Percebemos maiores volumes de vendas nas categorias 'cama_mesa_banho', 'beleza_saude', porém segue bem distribuidos com outras categorias com volumes próximos.

# %%
products = merged.groupby('product_category_name')['qtd_item'].count().reset_index()

# %%
import matplotlib.pyplot as plt

# Ordenando e pegando Top 10
top_products = products.sort_values(by='qtd_item', ascending=False).head(10)

# Criando o gráfico
plt.figure(figsize=(12,6))
plt.bar(top_products['product_category_name'], top_products['qtd_item'])

# Ajustes visuais
plt.title('Top 10 Categorias por Volume de Vendas')
plt.xlabel('Categoria do Produto')
plt.ylabel('Quantidade de Itens Vendidos')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# Esse gráfico é do tipo barra (bar chart). Ele é adequado, pois possibilita comparar entre as categorias e possibilita visuaizar as Top 10 categorias por volume de vendas (qtd_item).

# %% [markdown]
# **2. Quais categorias geram maior faturamento?**
#
#  Hipótese: As categorias mais vendidas não são necessariamente as mais lucrativas.
#
#  Análise: Soma do price por categoria.
#
#  Observa-se que algumas categorias, mesmo não liderando em volume, apresentam maior faturamento, indicando maior valor agregado por produto. Como vemos no gráfico abaixo os maiores valores de receita de venda derivam, das categorias 'beleza_saude' e 'relogios_presentes', somente em terceiro aparecendo o setor com o maior numero de vendas 'cama_mesa_banho'.

# %%
products_price = merged.groupby(['product_category_name']).agg({"price":"sum", "qtd_item":"count"})

# %%
import matplotlib.pyplot as plt

# Ordenando e pegando Top 10
top_faturamento = products_price.sort_values(by='price', ascending=False).head(10).reset_index()

# Criando o gráfico
plt.figure(figsize=(12,6))
plt.bar(top_faturamento['product_category_name'], top_faturamento['price'])

# Ajustes visuais
plt.title('Top 10 Categorias por Faturamento')
plt.xlabel('Categoria do Produto')
plt.ylabel('Faturamento Total (R$)')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# Também é do tipo barra (bar chart). Ele é adequado, pois permite a comparação dos valores e a classificação das categorias que obtiveram os 10 maiores faturamentos.

# %% [markdown]
# **3. Existe relação entre quantidade vendida e faturamento?**
#
# Hipótese: Existe correlação positiva entre quantidade de itens e faturamento.
#
# Análise:Comparação entre qtd_item e price.
#
# Há uma correlação positiva, porém não linear forte, indicando que o preço médio influencia significativamente o faturamento.

# %%
relacao = merged.groupby('product_category_name').agg({
    'qtd_item':'count',
    'price':'sum'
}).reset_index()

plt.figure(figsize=(8,6))
plt.scatter(relacao['qtd_item'], relacao['price'])

plt.title('Quantidade vs Faturamento por Categoria')
plt.xlabel('Quantidade de Itens')
plt.ylabel('Faturamento')
plt.tight_layout()
plt.show()

# %% [markdown]
# Aqui está utilizando o gráfico de dispersão (scatter plot). Ele é mais adequado para esta questão, pois permite ver há uma relação da quantidade de itens vendidos com o faturamento gerado, permitindo identificar tendências.

# %% [markdown]
# **4. Como as vendas estão distribuídas entre os estados?**
#
# Hipótese: Estados mais populosos concentram mais vendas.
#
# Análise: Agrupamento por customer_state.
#
# Estados como SP e RJ apresentam maior volume de vendas, refletindo densidade populacional e poder de consumo.

# %%
vendas_estado = merged.groupby('customer_state')['qtd_item'].count() \
    .sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(10,5))
plt.bar(vendas_estado['customer_state'], vendas_estado['qtd_item'])

plt.title('Top 10 Estados por Volume de Vendas')
plt.xlabel('Estado')
plt.ylabel('Quantidade de Itens')
plt.tight_layout()
plt.show()

# %% [markdown]
# Aqui utilizamos gráfico de barras para comparar o volume de vendas (quantiade de itens) nos estados, permitindo visualizar os 10 primeiros estados que possuem a maior quantidade de vendas realizadas.

# %% [markdown]
# **5. Existe variação significativa nas vendas entre cidades dentro do mesmo estado?**
#
# Hipótese: Mesmo dentro de um estado, há concentração em grandes centros urbanos.
#
# Análise: Agrupamento por customer_state e customer_city.
#
# As vendas são altamente concentradas em poucas cidades, o que pode gerar viés no modelo se não tratado.

# %%
vendas_cidade = merged.groupby(['customer_state','customer_city'])['qtd_item'].count() \
    .sort_values(ascending=False).head(10).reset_index()

labels = vendas_cidade['customer_city'] + " - " + vendas_cidade['customer_state']

plt.figure(figsize=(12,6))
plt.barh(labels, vendas_cidade['qtd_item'])

plt.title('Top 10 Cidades por Volume de Vendas')
plt.xlabel('Quantidade')
plt.ylabel('Cidade')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# Aqui também utilizamos o gráfico de barras horizontais para comparar o volume de vendas (quantidade de itens) entre as cidades dentro dos estados, permitindo visualizar as 10 cidades com maior volume de vendas.

# %% [markdown]
# **6. Como os preços estão distribuídos?**
#
# Hipótese: A distribuição de preços é assimétrica (skewed).
#
# Análise: Distribuição da variável price.
#
# A distribuição é assimétrica à direita, com muitos produtos baratos e poucos muito caros (outliers).

# %%
plt.figure(figsize=(8,6))
plt.hist(merged['price'], bins=50)

plt.title('Distribuição dos Preços')
plt.xlabel('Preço')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %% [markdown]
# Foi utilizado um histograma, pois possibilita visualizar a **distribuição** dos preços. Ele é o tipo de visualização mais adequado para esta pergunta porque permite analisar a distribuição dos preços e observar se existem padrões, como uma maior concentração em valores mais baixos ou mais altos.

# %% [markdown]
# **7. Existe variação temporal nas vendas?**
#
# Hipótese: As vendas variam ao longo do tempo (tendência ou sazonalidade).
#
# Análise: Agrupamento por order_purchase_timestamp.
#
# Há variações ao longo do tempo, indicando possíveis padrões sazonais que devem ser considerados no modelo de regressão.

# %%
vendas_tempo = merged.groupby('order_purchase_timestamp')['qtd_item'].count().reset_index()

plt.figure(figsize=(12,6))
plt.plot(vendas_tempo['order_purchase_timestamp'], vendas_tempo['qtd_item'])

plt.title('Vendas ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Quantidade de Itens')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Foi utilzado o gráfico de linha e ele é ideal para mostrar a variação de quantidade de itens vendidos ao longo do tempo, isso permite visualizar padrões sazonais .

# %% [markdown]
# **8. Pedidos com mais itens têm maior valor total?**
#
# Hipótese:Quanto maior a quantidade de itens, maior o valor total do pedido.
#
# Análise:** Relação entre qtd_item e price.
#
# Existe relação positiva, porém com alta variabilidade, indicando que pedidos grandes nem sempre são mais caros.

# %%
pedido = merged.groupby('order_id').agg({
    'qtd_item':'count',
    'price':'sum'
}).reset_index()

plt.figure(figsize=(8,6))
plt.scatter(pedido['qtd_item'], pedido['price'])

plt.title('Itens por Pedido vs Valor Total')
plt.xlabel('Quantidade de Itens')
plt.ylabel('Valor Total')
plt.tight_layout()
plt.show()

# %% [markdown]
# Aqui foi utilizado o gráfico de dispersão (scatter plot). Nesse caso, foi aplicado para verificar se há relação entre a quantidade de itens e o valor total dos pedidos, permitindo avaliar se pedidos com mais itens tendem a apresentar maior valor total.

# %% [markdown]
# **9. As categorias mais vendidas também são as mais bem avaliadas pelos clientes?**
#
# Hipótese: Categorias com maior volume de vendas não são necessariamente as mais bem avaliadas.
#
# Análise: Cruzamento entre product_category_name e review_score médio.
#
# A análise da relação entre volume de vendas e avaliação média, por meio de gráfico de dispersão e correlação, mostrou que não há associação significativa entre as variáveis (correlação ≈ 0.0280). Isso indica que categorias mais vendidas não são necessariamente as mais bem avaliadas pelos clientes, confirmando a hipótese inicial.

# %%
# Criando o DataFrame category_review agrupando por categoria e calculando o total de itens e a média da avaliação
category_review = merged.groupby('product_category_name').agg(
    total_items=('qtd_item', 'count'),
    avg_review_score=('review_score', 'mean')
).reset_index()

plt.figure(figsize=(8, 6))
plt.scatter(category_review['total_items'], category_review['avg_review_score'], alpha=0.6)

plt.title('Relação entre Volume de Vendas e Avaliação Média')
plt.xlabel('Volume de Vendas (total de itens)')
plt.ylabel('Avaliação Média')
plt.ylim(0, 5)

plt.grid(True)
plt.tight_layout()
plt.show()

# Correlação
correlation = category_review['total_items'].corr(category_review['avg_review_score'])
print(f'Correlação entre volume e avaliação: {correlation:.4f}')
# Out:
# Correlação entre volume e avaliação: -0.0119

# %% [markdown]
# Por fim, foi utilizado um gráfico de dispersão (scatter plot), pois esse tipo de visualização é adequado para analisar a relação entre duas variáveis numéricas, o volume de vendas e a avaliação média das categorias. Isso permite observar e identificar padrões ou correlações dos dados.

# %% [markdown]
# **Síntese Crítica dos Achados**
#
#  A análise exploratória revelou padrões importantes no comportamento das vendas do e-commerce:  Existe alta concentração de vendas em poucas categorias e regiões, o que pode gerar viés no modelo.  A relação entre variáveis como quantidade, preço e avaliação não é totalmente linear, o que pode limitar a performance da regressão linear simples.  A presença de distribuições assimétricas e possíveis outliers (principalmente em preço) pode impactar o modelo, sendo recomendável normalização ou transformação dos dados.  Foi identificada variação temporal nas vendas, indicando que variáveis de tempo são relevantes para previsão.  A influência da avaliação do cliente existe, mas é moderada, sugerindo que outros fatores têm maior peso.
